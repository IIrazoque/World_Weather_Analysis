# %%
# Import the dependencies.
import pandas as pd
import numpy as np
import time

# %%
# Import the API key.
from config import weather_api_key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#Create a new set of 2,000 random latitudes and longitudes
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy
import requests

# %%
#Retrieve the following information from the API call
#create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 780

# %%
# Create an endpoint URL
city_url = url + "&q=" + city.replace(" ","+")

# %%
# Parse the JSON and retrieve data.
city_weather = requests.get(city_url).json()

print(city_weather)
# Out:
# {'coord': {'lon': 100.4517, 'lat': 38.9342}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 83.53, 'feels_like': 81.09, 'temp_min': 83.53, 'temp_max': 83.53, 'pressure': 1000, 'humidity': 23, 'sea_level': 1000, 'grnd_level': 848}, 'visibility': 10000, 'wind': {'speed': 4.52, 'deg': 108, 'gust': 4.7}, 'clouds': {'all': 93}, 'dt': 1656819949, 'sys': {'country': 'CN', 'sunrise': 1656799023, 'sunset': 1656852438}, 'timezone': 28800, 'id': 1785036, 'name': 'Zhangye', 'cod': 200}

# %%
#retrieve weather description from an API call
city_weather["weather"][0]["description"]
# Out:
# 'overcast clouds'

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1


# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
   
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_descript = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                         "Current Description": city_weather_descript})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

    # Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 1 | herbertpur
# Processing Record 3 of Set 1 | cape town
# Processing Record 4 of Set 1 | vanimo
# Processing Record 5 of Set 1 | kavali
# Processing Record 6 of Set 1 | ribeira grande
# Processing Record 7 of Set 1 | acapulco
# Processing Record 8 of Set 1 | arraial do cabo
# Processing Record 9 of Set 1 | vaini
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | mataura
# Processing Record 12 of Set 1 | albany
# Processing Record 13 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 14 of Set 1 | lata
# Processing Record 15 of Set 1 | khatanga
# Processing Record 16 of Set 1 | barrow
# Processing Record 17 of Set 1 | lahore
# Processing Record 18 of Set 1 | hermanus
# Processing Record 19 of Set 1 | mahebourg
# Processing Record 20 of Set 1 | saint-philippe
# Processing Record 21 of Set 1 | bambous virieux
# Processing Record 22 of Set 1 | kununurra
# Processing Record 23 of Set 1 | victoria
# Processing Record 24 of Set 1 | upernavik
# Processing Record 25 of Set 1 | ushuaia
# Processing Record 26 of Set 1 | kapaa
# Processing Record 27 of Set 1 | north bend
# Processing Record 28 of Set 1 | touros
# Processing Record 29 of Set 1 | busselton
# Processing Record 30 of Set 1 | santiago
# Processing Record 31 of Set 1 | bredasdorp
# Processing Record 32 of Set 1 | muroto
# Processing Record 33 of Set 1 | ostrovnoy
# Processing Record 34 of Set 1 | manbij
# Processing Record 35 of Set 1 | chern
# Processing Record 36 of Set 1 | chumikan
# Processing Record 37 of Set 1 | jamestown
# Processing Record 38 of Set 1 | san patricio
# Processing Record 39 of Set 1 | bluff
# Processing Record 40 of Set 1 | kysyl-syr
# Processing Record 41 of Set 1 | atuona
# Processing Record 42 of Set 1 | sibolga
# Processing Record 43 of Set 1 | new norfolk
# Processing Record 44 of Set 1 | xai-xai
# Processing Record 45 of Set 1 | solnechnyy
# Processing Record 46 of Set 1 | jasper
# Processing Record 47 of Set 1 | dikson
# Processing Record 48 of Set 1 | norman wells
# Processing Record 49 of Set 1 | longyearbyen
# Processing Record 50 of Set 1 | whitehorse
# Processing Record 1 of Set 2 | emerald
# Processing Record 2 of Set 2 | narsaq
# Processing Record 3 of Set 2 | torbay
# Processing Record 4 of Set 2 | ulagan
# Processing Record 5 of Set 2 | beringovskiy
# Processing Record 6 of Set 2 | lianzhou
# Processing Record 7 of Set 2 | sao filipe
# Processing Record 8 of Set 2 | broken hill
# Processing Record 9 of Set 2 | honningsvag
# Processing Record 10 of Set 2 | seshcha
# Processing Record 11 of Set 2 | byron bay
# Processing Record 12 of Set 2 | shunyi
# Processing Record 13 of Set 2 | souillac
# Processing Record 14 of Set 2 | marsa matruh
# Processing Record 15 of Set 2 | seminole
# Processing Record 16 of Set 2 | carnarvon
# Processing Record 17 of Set 2 | guerrero negro
# Processing Record 18 of Set 2 | tasiilaq
# Processing Record 19 of Set 2 | lebu
# Processing Record 20 of Set 2 | paamiut
# Processing Record 21 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 22 of Set 2 | punta arenas
# Processing Record 23 of Set 2 | sikandra rao
# Processing Record 24 of Set 2 | chokurdakh
# Processing Record 25 of Set 2 | bangangte
# Processing Record 26 of Set 2 | isla vista
# Processing Record 27 of Set 2 | saint george
# Processing Record 28 of Set 2 | hobart
# Processing Record 29 of Set 2 | russell
# Processing Record 30 of Set 2 | kaitangata
# Processing Record 31 of Set 2 | yar-sale
# Processing Record 32 of Set 2 | puerto ayora
# Processing Record 33 of Set 2 | cayenne
# Processing Record 34 of Set 2 | avarua
# Processing Record 35 of Set 2 | kanpur
# Processing Record 36 of Set 2 | rorvik
# Processing Record 37 of Set 2 | banat
# Processing Record 38 of Set 2 | sitka
# Processing Record 39 of Set 2 | sept-iles
# Processing Record 40 of Set 2 | broome
# Processing Record 41 of Set 2 | port alfred
# Processing Record 42 of Set 2 | bengkulu
# Processing Record 43 of Set 2 | avera
# Processing Record 44 of Set 2 | lasa
# Processing Record 45 of Set 2 | port elizabeth
# Processing Record 46 of Set 2 | ambilobe
# Processing Record 47 of Set 2 | gushikawa
# Processing Record 48 of Set 2 | saint-pierre
# Processing Record 49 of Set 2 | kenora
# Processing Record 50 of Set 2 | east london
# Processing Record 1 of Set 3 | karasuk
# Processing Record 2 of Set 3 | sisimiut
# Processing Record 3 of Set 3 | georgetown
# Processing Record 4 of Set 3 | balkanabat
# Processing Record 5 of Set 3 | hobyo
# Processing Record 6 of Set 3 | ossora
# Processing Record 7 of Set 3 | mudyuga
# City not found. Skipping...
# Processing Record 8 of Set 3 | husavik
# Processing Record 9 of Set 3 | amahai
# Processing Record 10 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 11 of Set 3 | kruisfontein
# Processing Record 12 of Set 3 | takaungu
# Processing Record 13 of Set 3 | yellowknife
# Processing Record 14 of Set 3 | candido de abreu
# Processing Record 15 of Set 3 | tateyama
# Processing Record 16 of Set 3 | thompson
# Processing Record 17 of Set 3 | mar del plata
# Processing Record 18 of Set 3 | belen
# Processing Record 19 of Set 3 | manta
# Processing Record 20 of Set 3 | iqaluit
# Processing Record 21 of Set 3 | kyra
# Processing Record 22 of Set 3 | namibe
# Processing Record 23 of Set 3 | hithadhoo
# Processing Record 24 of Set 3 | butaritari
# Processing Record 25 of Set 3 | nueva gerona
# Processing Record 26 of Set 3 | castro
# Processing Record 27 of Set 3 | tuktoyaktuk
# Processing Record 28 of Set 3 | elko
# Processing Record 29 of Set 3 | havre-saint-pierre
# Processing Record 30 of Set 3 | ancud
# Processing Record 31 of Set 3 | el carrizo
# Processing Record 32 of Set 3 | hilo
# Processing Record 33 of Set 3 | dafeng
# Processing Record 34 of Set 3 | kieta
# Processing Record 35 of Set 3 | alanya
# Processing Record 36 of Set 3 | kahului
# Processing Record 37 of Set 3 | chimbote
# Processing Record 38 of Set 3 | acajutiba
# Processing Record 39 of Set 3 | easton
# Processing Record 40 of Set 3 | salalah
# Processing Record 41 of Set 3 | bonthe
# Processing Record 42 of Set 3 | bam
# Processing Record 43 of Set 3 | tuatapere
# Processing Record 44 of Set 3 | hualmay
# Processing Record 45 of Set 3 | haibowan
# City not found. Skipping...
# Processing Record 46 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 47 of Set 3 | cidreira
# Processing Record 48 of Set 3 | gardner
# Processing Record 49 of Set 3 | dehloran
# Processing Record 50 of Set 3 | manadhoo
# Processing Record 1 of Set 4 | eureka
# Processing Record 2 of Set 4 | nigran
# Processing Record 3 of Set 4 | kuusamo
# Processing Record 4 of Set 4 | pisco
# Processing Record 5 of Set 4 | tadine
# Processing Record 6 of Set 4 | mastic beach
# Processing Record 7 of Set 4 | zhireken
# Processing Record 8 of Set 4 | nairobi
# Processing Record 9 of Set 4 | plavinas
# Processing Record 10 of Set 4 | zabaykalsk
# Processing Record 11 of Set 4 | lompoc
# Processing Record 12 of Set 4 | meulaboh
# Processing Record 13 of Set 4 | chandler
# Processing Record 14 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 15 of Set 4 | garden city
# Processing Record 16 of Set 4 | alofi
# Processing Record 17 of Set 4 | turgenevo
# Processing Record 18 of Set 4 | taozhuang
# Processing Record 19 of Set 4 | zhuhai
# Processing Record 20 of Set 4 | klaksvik
# Processing Record 21 of Set 4 | cherskiy
# Processing Record 22 of Set 4 | ballstad
# City not found. Skipping...
# Processing Record 23 of Set 4 | gravdal
# Processing Record 24 of Set 4 | flagstaff
# Processing Record 25 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 26 of Set 4 | takoradi
# Processing Record 27 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 28 of Set 4 | mgandu
# Processing Record 29 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 30 of Set 4 | agadez
# Processing Record 31 of Set 4 | shelburne
# Processing Record 32 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 33 of Set 4 | cordoba
# Processing Record 34 of Set 4 | bethel
# Processing Record 35 of Set 4 | lubango
# Processing Record 36 of Set 4 | kodiak
# Processing Record 37 of Set 4 | lagoa
# Processing Record 38 of Set 4 | yumen
# Processing Record 39 of Set 4 | lebedinyy
# Processing Record 40 of Set 4 | ponta do sol
# Processing Record 41 of Set 4 | esperance
# Processing Record 42 of Set 4 | nome
# Processing Record 43 of Set 4 | hasaki
# Processing Record 44 of Set 4 | wasilla
# Processing Record 45 of Set 4 | vila
# Processing Record 46 of Set 4 | macaboboni
# City not found. Skipping...
# Processing Record 47 of Set 4 | vestmannaeyjar
# Processing Record 48 of Set 4 | kato soulion
# Processing Record 49 of Set 4 | takanosu
# Processing Record 50 of Set 4 | sangar
# Processing Record 1 of Set 5 | buluang
# Processing Record 2 of Set 5 | qaanaaq
# Processing Record 3 of Set 5 | saint-augustin
# Processing Record 4 of Set 5 | podporozhye
# Processing Record 5 of Set 5 | sajanan
# Processing Record 6 of Set 5 | topolobampo
# Processing Record 7 of Set 5 | ventspils
# Processing Record 8 of Set 5 | oytal
# Processing Record 9 of Set 5 | wuwei
# Processing Record 10 of Set 5 | zhangjiakou
# Processing Record 11 of Set 5 | maunabo
# Processing Record 12 of Set 5 | saint-francois
# Processing Record 13 of Set 5 | satun
# Processing Record 14 of Set 5 | port shepstone
# Processing Record 15 of Set 5 | ulladulla
# Processing Record 16 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 17 of Set 5 | savonlinna
# Processing Record 18 of Set 5 | misratah
# Processing Record 19 of Set 5 | boguchany
# Processing Record 20 of Set 5 | cienfuegos
# Processing Record 21 of Set 5 | saskylakh
# Processing Record 22 of Set 5 | lorengau
# Processing Record 23 of Set 5 | oruro
# Processing Record 24 of Set 5 | nikolskoye
# Processing Record 25 of Set 5 | eyl
# Processing Record 26 of Set 5 | boa vista
# Processing Record 27 of Set 5 | grand gaube
# Processing Record 28 of Set 5 | coquimbo
# Processing Record 29 of Set 5 | fenyi
# Processing Record 30 of Set 5 | the valley
# Processing Record 31 of Set 5 | puerto cabello
# Processing Record 32 of Set 5 | ust-tsilma
# Processing Record 33 of Set 5 | sioux lookout
# Processing Record 34 of Set 5 | yulara
# Processing Record 35 of Set 5 | port blair
# Processing Record 36 of Set 5 | chaa-khol
# City not found. Skipping...
# Processing Record 37 of Set 5 | chagda
# City not found. Skipping...
# Processing Record 38 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 39 of Set 5 | mecca
# Processing Record 40 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 41 of Set 5 | chapada dos guimaraes
# Processing Record 42 of Set 5 | codrington
# Processing Record 43 of Set 5 | ecublens
# Processing Record 44 of Set 5 | airai
# Processing Record 45 of Set 5 | namwala
# Processing Record 46 of Set 5 | hagi
# Processing Record 47 of Set 5 | vigrestad
# Processing Record 48 of Set 5 | tongren
# Processing Record 49 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 50 of Set 5 | melfort
# Processing Record 1 of Set 6 | nioro
# Processing Record 2 of Set 6 | angren
# Processing Record 3 of Set 6 | clyde river
# Processing Record 4 of Set 6 | ksenyevka
# City not found. Skipping...
# Processing Record 5 of Set 6 | chuy
# Processing Record 6 of Set 6 | faanui
# Processing Record 7 of Set 6 | oktyabrskoye
# Processing Record 8 of Set 6 | deputatskiy
# Processing Record 9 of Set 6 | mount gambier
# Processing Record 10 of Set 6 | agua verde
# Processing Record 11 of Set 6 | beloha
# Processing Record 12 of Set 6 | vitimskiy
# City not found. Skipping...
# Processing Record 13 of Set 6 | manzhouli
# Processing Record 14 of Set 6 | hovd
# Processing Record 15 of Set 6 | dingle
# Processing Record 16 of Set 6 | nelson bay
# Processing Record 17 of Set 6 | korla
# Processing Record 18 of Set 6 | yaan
# Processing Record 19 of Set 6 | vaitape
# Processing Record 20 of Set 6 | liberal
# Processing Record 21 of Set 6 | udachnyy
# Processing Record 22 of Set 6 | port lincoln
# Processing Record 23 of Set 6 | tupik
# Processing Record 24 of Set 6 | qianan
# Processing Record 25 of Set 6 | zheleznodorozhnyy
# Processing Record 26 of Set 6 | lamar
# Processing Record 27 of Set 6 | vardo
# Processing Record 28 of Set 6 | burica
# City not found. Skipping...
# Processing Record 29 of Set 6 | merauke
# Processing Record 30 of Set 6 | sao raimundo nonato
# Processing Record 31 of Set 6 | alabaster
# Processing Record 32 of Set 6 | capoterra
# Processing Record 33 of Set 6 | zhigansk
# Processing Record 34 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 35 of Set 6 | temaraia
# City not found. Skipping...
# Processing Record 36 of Set 6 | myronivka
# Processing Record 37 of Set 6 | leningradskiy
# Processing Record 38 of Set 6 | yeppoon
# Processing Record 39 of Set 6 | buckeye
# Processing Record 40 of Set 6 | tura
# Processing Record 41 of Set 6 | houma
# Processing Record 42 of Set 6 | luderitz
# Processing Record 43 of Set 6 | geraldton
# Processing Record 44 of Set 6 | bageshwar
# Processing Record 45 of Set 6 | mantua
# Processing Record 46 of Set 6 | aripuana
# Processing Record 47 of Set 6 | namatanai
# Processing Record 48 of Set 6 | ratnagiri
# Processing Record 49 of Set 6 | saldanha
# Processing Record 50 of Set 6 | chiungutwa
# Processing Record 1 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 2 of Set 7 | pevek
# Processing Record 3 of Set 7 | praya
# Processing Record 4 of Set 7 | lexington
# Processing Record 5 of Set 7 | puerto colombia
# Processing Record 6 of Set 7 | wana
# Processing Record 7 of Set 7 | watsa
# Processing Record 8 of Set 7 | aklavik
# Processing Record 9 of Set 7 | moindou
# Processing Record 10 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 11 of Set 7 | praia da vitoria
# Processing Record 12 of Set 7 | bathsheba
# Processing Record 13 of Set 7 | taitung
# Processing Record 14 of Set 7 | kozhva
# Processing Record 15 of Set 7 | rojhan
# Processing Record 16 of Set 7 | kavieng
# Processing Record 17 of Set 7 | tiksi
# Processing Record 18 of Set 7 | mombasa
# Processing Record 19 of Set 7 | elbistan
# Processing Record 20 of Set 7 | tibiri
# Processing Record 21 of Set 7 | maple creek
# Processing Record 22 of Set 7 | karratha
# Processing Record 23 of Set 7 | praia
# Processing Record 24 of Set 7 | bontang
# Processing Record 25 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 26 of Set 7 | namanga
# Processing Record 27 of Set 7 | sao joaquim
# Processing Record 28 of Set 7 | raudeberg
# Processing Record 29 of Set 7 | mackay
# Processing Record 30 of Set 7 | ko samui
# Processing Record 31 of Set 7 | toucheng
# Processing Record 32 of Set 7 | santa rosa
# Processing Record 33 of Set 7 | swift current
# Processing Record 34 of Set 7 | tondano
# Processing Record 35 of Set 7 | da lat
# Processing Record 36 of Set 7 | mezen
# Processing Record 37 of Set 7 | comodoro rivadavia
# Processing Record 38 of Set 7 | putatan
# Processing Record 39 of Set 7 | dubbo
# Processing Record 40 of Set 7 | axim
# Processing Record 41 of Set 7 | richards bay
# Processing Record 42 of Set 7 | takab
# Processing Record 43 of Set 7 | khonuu
# City not found. Skipping...
# Processing Record 44 of Set 7 | aykhal
# Processing Record 45 of Set 7 | katsuura
# Processing Record 46 of Set 7 | winnemucca
# Processing Record 47 of Set 7 | hofn
# Processing Record 48 of Set 7 | santa isabel
# Processing Record 49 of Set 7 | shimoda
# Processing Record 50 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 1 of Set 8 | abu samrah
# Processing Record 2 of Set 8 | fukue
# Processing Record 3 of Set 8 | pitimbu
# Processing Record 4 of Set 8 | santa vitoria do palmar
# Processing Record 5 of Set 8 | walvis bay
# Processing Record 6 of Set 8 | choa saidan shah
# Processing Record 7 of Set 8 | sur
# Processing Record 8 of Set 8 | bowen
# Processing Record 9 of Set 8 | taoudenni
# Processing Record 10 of Set 8 | valparaiso
# Processing Record 11 of Set 8 | dolbeau
# City not found. Skipping...
# Processing Record 12 of Set 8 | yakeshi
# Processing Record 13 of Set 8 | barao de melgaco
# Processing Record 14 of Set 8 | ornes
# Processing Record 15 of Set 8 | darhan
# Processing Record 16 of Set 8 | kedougou
# Processing Record 17 of Set 8 | witham
# Processing Record 18 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 19 of Set 8 | komsomolskiy
# Processing Record 20 of Set 8 | neuquen
# Processing Record 21 of Set 8 | severo-kurilsk
# Processing Record 22 of Set 8 | carutapera
# Processing Record 23 of Set 8 | carlsbad
# Processing Record 24 of Set 8 | rodrigues alves
# Processing Record 25 of Set 8 | noshiro
# Processing Record 26 of Set 8 | rawannawi
# City not found. Skipping...
# Processing Record 27 of Set 8 | newport
# Processing Record 28 of Set 8 | evensk
# Processing Record 29 of Set 8 | nhulunbuy
# Processing Record 30 of Set 8 | harper
# Processing Record 31 of Set 8 | itupiranga
# Processing Record 32 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 33 of Set 8 | jardim
# Processing Record 34 of Set 8 | godda
# Processing Record 35 of Set 8 | kenai
# Processing Record 36 of Set 8 | xining
# Processing Record 37 of Set 8 | krasnoselkup
# Processing Record 38 of Set 8 | longlac
# City not found. Skipping...
# Processing Record 39 of Set 8 | boma
# Processing Record 40 of Set 8 | mayo
# Processing Record 41 of Set 8 | channel-port aux basques
# Processing Record 42 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 43 of Set 8 | aykino
# Processing Record 44 of Set 8 | puerto escondido
# Processing Record 45 of Set 8 | la union
# Processing Record 46 of Set 8 | gerash
# Processing Record 47 of Set 8 | kayattar
# Processing Record 48 of Set 8 | provideniya
# Processing Record 49 of Set 8 | naryan-mar
# Processing Record 50 of Set 8 | san isidro
# Processing Record 1 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 2 of Set 9 | horsham
# Processing Record 3 of Set 9 | dunedin
# Processing Record 4 of Set 9 | port hardy
# Processing Record 5 of Set 9 | coudekerque-branche
# Processing Record 6 of Set 9 | lavrentiya
# Processing Record 7 of Set 9 | talcahuano
# Processing Record 8 of Set 9 | kalaleh
# Processing Record 9 of Set 9 | maragogi
# Processing Record 10 of Set 9 | tabas
# Processing Record 11 of Set 9 | hay river
# Processing Record 12 of Set 9 | taltal
# Processing Record 13 of Set 9 | nata
# Processing Record 14 of Set 9 | andenes
# Processing Record 15 of Set 9 | zhezkazgan
# Processing Record 16 of Set 9 | mayumba
# Processing Record 17 of Set 9 | vila velha
# Processing Record 18 of Set 9 | puerto madryn
# Processing Record 19 of Set 9 | devonport
# Processing Record 20 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 21 of Set 9 | candawaga
# City not found. Skipping...
# Processing Record 22 of Set 9 | naze
# Processing Record 23 of Set 9 | isangel
# Processing Record 24 of Set 9 | cocachacra
# Processing Record 25 of Set 9 | adre
# Processing Record 26 of Set 9 | ulaangom
# Processing Record 27 of Set 9 | san cristobal
# Processing Record 28 of Set 9 | blagoyevo
# Processing Record 29 of Set 9 | changji
# Processing Record 30 of Set 9 | ilulissat
# Processing Record 31 of Set 9 | nongan
# Processing Record 32 of Set 9 | ferme-neuve
# Processing Record 33 of Set 9 | tazovskiy
# Processing Record 34 of Set 9 | adiake
# Processing Record 35 of Set 9 | pangnirtung
# Processing Record 36 of Set 9 | grindavik
# Processing Record 37 of Set 9 | kondoa
# Processing Record 38 of Set 9 | maumere
# Processing Record 39 of Set 9 | innisfail
# Processing Record 40 of Set 9 | chuka
# Processing Record 41 of Set 9 | awjilah
# Processing Record 42 of Set 9 | banatski karlovac
# Processing Record 43 of Set 9 | auki
# Processing Record 44 of Set 9 | canon city
# Processing Record 45 of Set 9 | kugulta
# Processing Record 46 of Set 9 | phan rang
# City not found. Skipping...
# Processing Record 47 of Set 9 | golpayegan
# Processing Record 48 of Set 9 | christchurch
# Processing Record 49 of Set 9 | constitucion
# Processing Record 50 of Set 9 | quatre cocos
# Processing Record 1 of Set 10 | lucea
# Processing Record 2 of Set 10 | linxia
# Processing Record 3 of Set 10 | san quintin
# Processing Record 4 of Set 10 | portland
# Processing Record 5 of Set 10 | nanortalik
# Processing Record 6 of Set 10 | costa rica
# Processing Record 7 of Set 10 | syamzha
# Processing Record 8 of Set 10 | pasighat
# Processing Record 9 of Set 10 | camana
# Processing Record 10 of Set 10 | kaeo
# Processing Record 11 of Set 10 | tshikapa
# Processing Record 12 of Set 10 | khandyga
# Processing Record 13 of Set 10 | mbuji-mayi
# Processing Record 14 of Set 10 | longhua
# Processing Record 15 of Set 10 | avallon
# Processing Record 16 of Set 10 | honiara
# Processing Record 17 of Set 10 | margate
# Processing Record 18 of Set 10 | santa
# Processing Record 19 of Set 10 | loding
# Processing Record 20 of Set 10 | muana
# Processing Record 21 of Set 10 | linfen
# Processing Record 22 of Set 10 | karasburg
# Processing Record 23 of Set 10 | mineiros
# Processing Record 24 of Set 10 | sambava
# Processing Record 25 of Set 10 | cervo
# Processing Record 26 of Set 10 | donetsk
# Processing Record 27 of Set 10 | mama
# Processing Record 28 of Set 10 | rio grande
# Processing Record 29 of Set 10 | enid
# Processing Record 30 of Set 10 | manado
# Processing Record 31 of Set 10 | flin flon
# Processing Record 32 of Set 10 | cabedelo
# Processing Record 33 of Set 10 | kanker
# Processing Record 34 of Set 10 | sehithwa
# Processing Record 35 of Set 10 | santarem
# Processing Record 36 of Set 10 | carauari
# Processing Record 37 of Set 10 | toftir
# City not found. Skipping...
# Processing Record 38 of Set 10 | holstebro
# Processing Record 39 of Set 10 | kartarpur
# Processing Record 40 of Set 10 | salinas
# Processing Record 41 of Set 10 | shingu
# Processing Record 42 of Set 10 | karkaralinsk
# City not found. Skipping...
# Processing Record 43 of Set 10 | methven
# Processing Record 44 of Set 10 | rudnyy
# Processing Record 45 of Set 10 | la ronge
# Processing Record 46 of Set 10 | anahuac
# Processing Record 47 of Set 10 | camocim
# Processing Record 48 of Set 10 | riohacha
# Processing Record 49 of Set 10 | moose factory
# Processing Record 50 of Set 10 | yekaterinovka
# Processing Record 1 of Set 11 | boueni
# Processing Record 2 of Set 11 | dvinskoy
# Processing Record 3 of Set 11 | alyangula
# Processing Record 4 of Set 11 | boende
# Processing Record 5 of Set 11 | parita
# Processing Record 6 of Set 11 | eregli
# Processing Record 7 of Set 11 | labuhan
# Processing Record 8 of Set 11 | uyskoye
# Processing Record 9 of Set 11 | antsohihy
# Processing Record 10 of Set 11 | iberia
# Processing Record 11 of Set 11 | kishapu
# Processing Record 12 of Set 11 | marrakesh
# Processing Record 13 of Set 11 | cairns
# Processing Record 14 of Set 11 | ternate
# Processing Record 15 of Set 11 | guiyang
# Processing Record 16 of Set 11 | haines junction
# Processing Record 17 of Set 11 | mercedes
# Processing Record 18 of Set 11 | tessalit
# Processing Record 19 of Set 11 | ponta delgada
# Processing Record 20 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 21 of Set 11 | itarantim
# Processing Record 22 of Set 11 | daru
# Processing Record 23 of Set 11 | visnes
# Processing Record 24 of Set 11 | kavaratti
# Processing Record 25 of Set 11 | tarko-sale
# Processing Record 26 of Set 11 | chernyshevskiy
# Processing Record 27 of Set 11 | mnogovershinnyy
# Processing Record 28 of Set 11 | tiznit
# Processing Record 29 of Set 11 | lydenburg
# Processing Record 30 of Set 11 | at-bashi
# Processing Record 31 of Set 11 | ejura
# Processing Record 32 of Set 11 | kayanga
# Processing Record 33 of Set 11 | narok
# Processing Record 34 of Set 11 | blackwater
# Processing Record 35 of Set 11 | jutai
# Processing Record 36 of Set 11 | bajo baudo
# City not found. Skipping...
# Processing Record 37 of Set 11 | curitibanos
# Processing Record 38 of Set 11 | tromso
# Processing Record 39 of Set 11 | hope
# Processing Record 40 of Set 11 | laguna
# Processing Record 41 of Set 11 | neepawa
# Processing Record 42 of Set 11 | juneau
# Processing Record 43 of Set 11 | mansfield
# Processing Record 44 of Set 11 | laja
# Processing Record 45 of Set 11 | padang
# Processing Record 46 of Set 11 | jalu
# Processing Record 47 of Set 11 | rawson
# Processing Record 48 of Set 11 | huarmey
# Processing Record 49 of Set 11 | inta
# Processing Record 50 of Set 11 | novaya malykla
# Processing Record 1 of Set 12 | kindu
# Processing Record 2 of Set 12 | sao joao da barra
# Processing Record 3 of Set 12 | gaoyou
# Processing Record 4 of Set 12 | tsiroanomandidy
# Processing Record 5 of Set 12 | kentau
# Processing Record 6 of Set 12 | bac lieu
# Processing Record 7 of Set 12 | compostela
# Processing Record 8 of Set 12 | anloga
# Processing Record 9 of Set 12 | tamandare
# Processing Record 10 of Set 12 | yambio
# Processing Record 11 of Set 12 | mweka
# Processing Record 12 of Set 12 | lensk
# Processing Record 13 of Set 12 | ruatoria
# City not found. Skipping...
# Processing Record 14 of Set 12 | de panne
# Processing Record 15 of Set 12 | talnakh
# Processing Record 16 of Set 12 | half moon bay
# Processing Record 17 of Set 12 | uvinza
# Processing Record 18 of Set 12 | paola
# Processing Record 19 of Set 12 | umm durman
# City not found. Skipping...
# Processing Record 20 of Set 12 | challans
# Processing Record 21 of Set 12 | aitape
# Processing Record 22 of Set 12 | manavgat
# Processing Record 23 of Set 12 | eldikan
# City not found. Skipping...
# Processing Record 24 of Set 12 | linshu
# City not found. Skipping...
# Processing Record 25 of Set 12 | nantucket
# Processing Record 26 of Set 12 | celestun
# Processing Record 27 of Set 12 | nouadhibou
# Processing Record 28 of Set 12 | farafangana
# Processing Record 29 of Set 12 | sapa
# Processing Record 30 of Set 12 | vostok
# Processing Record 31 of Set 12 | copiapo
# Processing Record 32 of Set 12 | tezu
# Processing Record 33 of Set 12 | magherani
# Processing Record 34 of Set 12 | hamilton
# Processing Record 35 of Set 12 | inhambane
# Processing Record 36 of Set 12 | rafai
# Processing Record 37 of Set 12 | ugoofaaru
# Processing Record 38 of Set 12 | cabo san lucas
# Processing Record 39 of Set 12 | moscow
# Processing Record 40 of Set 12 | san-pedro
# Processing Record 41 of Set 12 | bar harbor
# Processing Record 42 of Set 12 | vung tau
# Processing Record 43 of Set 12 | fortuna
# Processing Record 44 of Set 12 | cap malheureux
# Processing Record 45 of Set 12 | kokopo
# Processing Record 46 of Set 12 | ust-kulom
# Processing Record 47 of Set 12 | general pico
# Processing Record 48 of Set 12 | arona
# Processing Record 49 of Set 12 | tawzar
# City not found. Skipping...
# Processing Record 50 of Set 12 | puerto penasco
# Processing Record 1 of Set 13 | sao paulo de olivenca
# Processing Record 2 of Set 13 | bafq
# Processing Record 3 of Set 13 | lazdijai
# Processing Record 4 of Set 13 | cockburn town
# Processing Record 5 of Set 13 | jacareacanga
# Processing Record 6 of Set 13 | marinette
# Processing Record 7 of Set 13 | marsaxlokk
# Processing Record 8 of Set 13 | xuddur
# Processing Record 9 of Set 13 | sakakah
# Processing Record 10 of Set 13 | cozumel
# Processing Record 11 of Set 13 | mao
# Processing Record 12 of Set 13 | ponte san pietro
# Processing Record 13 of Set 13 | anadyr
# Processing Record 14 of Set 13 | saint-georges
# Processing Record 15 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 16 of Set 13 | waddan
# Processing Record 17 of Set 13 | ahipara
# Processing Record 18 of Set 13 | lashio
# Processing Record 19 of Set 13 | adrar
# Processing Record 20 of Set 13 | sofiysk
# City not found. Skipping...
# Processing Record 21 of Set 13 | kiruna
# Processing Record 22 of Set 13 | caninde
# Processing Record 23 of Set 13 | simao
# Processing Record 24 of Set 13 | metro
# Processing Record 25 of Set 13 | bartlesville
# Processing Record 26 of Set 13 | yanan
# City not found. Skipping...
# Processing Record 27 of Set 13 | ville-marie
# Processing Record 28 of Set 13 | waingapu
# Processing Record 29 of Set 13 | pinega
# Processing Record 30 of Set 13 | douglas
# Processing Record 31 of Set 13 | mindelo
# Processing Record 32 of Set 13 | hervey bay
# Processing Record 33 of Set 13 | nouakchott
# Processing Record 34 of Set 13 | te anau
# Processing Record 35 of Set 13 | naron
# Processing Record 36 of Set 13 | kapuskasing
# Processing Record 37 of Set 13 | cookeville
# Processing Record 38 of Set 13 | alexandria
# Processing Record 39 of Set 13 | hongjiang
# Processing Record 40 of Set 13 | shenxian
# Processing Record 41 of Set 13 | taunsa
# Processing Record 42 of Set 13 | itarema
# Processing Record 43 of Set 13 | umm lajj
# Processing Record 44 of Set 13 | halifax
# Processing Record 45 of Set 13 | kupino
# Processing Record 46 of Set 13 | okha
# Processing Record 47 of Set 13 | beyneu
# Processing Record 48 of Set 13 | soyo
# Processing Record 49 of Set 13 | atlantic city
# Processing Record 50 of Set 13 | altay
# Processing Record 1 of Set 14 | chapais
# Processing Record 2 of Set 14 | lazaro cardenas
# Processing Record 3 of Set 14 | ola
# Processing Record 4 of Set 14 | mansehra
# Processing Record 5 of Set 14 | puranpur
# Processing Record 6 of Set 14 | sobolevo
# Processing Record 7 of Set 14 | mirina
# City not found. Skipping...
# Processing Record 8 of Set 14 | vila franca do campo
# Processing Record 9 of Set 14 | pascagoula
# Processing Record 10 of Set 14 | calvinia
# Processing Record 11 of Set 14 | lahij
# Processing Record 12 of Set 14 | engenheiro beltrao
# Processing Record 13 of Set 14 | tres arroyos
# Processing Record 14 of Set 14 | haligue
# Processing Record 15 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 16 of Set 14 | micheweni
# Processing Record 17 of Set 14 | pochutla
# Processing Record 18 of Set 14 | maniitsoq
# Processing Record 19 of Set 14 | la macarena
# Processing Record 20 of Set 14 | leh
# Processing Record 21 of Set 14 | kibre mengist
# Processing Record 22 of Set 14 | jiayuguan
# Processing Record 23 of Set 14 | nemuro
# Processing Record 24 of Set 14 | kurilsk
# Processing Record 25 of Set 14 | morros
# Processing Record 26 of Set 14 | kaseda
# Processing Record 27 of Set 14 | paramirim
# Processing Record 28 of Set 14 | hambantota
# Processing Record 29 of Set 14 | vestmanna
# Processing Record 30 of Set 14 | weatherford
# Processing Record 31 of Set 14 | sembakung
# Processing Record 32 of Set 14 | teya
# Processing Record 33 of Set 14 | muli
# Processing Record 34 of Set 14 | mukhen
# Processing Record 35 of Set 14 | forbes
# Processing Record 36 of Set 14 | lakatoro
# Processing Record 37 of Set 14 | pauini
# Processing Record 38 of Set 14 | dhanwar
# Processing Record 39 of Set 14 | thinadhoo
# Processing Record 40 of Set 14 | yerbogachen
# Processing Record 41 of Set 14 | kinanah
# City not found. Skipping...
# Processing Record 42 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 43 of Set 14 | tidore
# City not found. Skipping...
# Processing Record 44 of Set 14 | kjollefjord
# Processing Record 45 of Set 14 | hokitika
# Processing Record 46 of Set 14 | bage
# Processing Record 47 of Set 14 | port-gentil
# Processing Record 48 of Set 14 | sendhwa
# Processing Record 49 of Set 14 | dzhusaly
# City not found. Skipping...
# Processing Record 50 of Set 14 | aleksandrov gay
# Processing Record 1 of Set 15 | coihaique
# Processing Record 2 of Set 15 | skagastrond
# City not found. Skipping...
# Processing Record 3 of Set 15 | labutta
# City not found. Skipping...
# Processing Record 4 of Set 15 | louga
# Processing Record 5 of Set 15 | temple
# Processing Record 6 of Set 15 | noumea
# Processing Record 7 of Set 15 | rincon
# Processing Record 8 of Set 15 | messina
# Processing Record 9 of Set 15 | xiaoshi
# Processing Record 10 of Set 15 | kawalu
# Processing Record 11 of Set 15 | angoche
# Processing Record 12 of Set 15 | port hedland
# Processing Record 13 of Set 15 | porto novo
# Processing Record 14 of Set 15 | carbonear
# Processing Record 15 of Set 15 | kushmurun
# Processing Record 16 of Set 15 | kampot
# Processing Record 17 of Set 15 | college
# Processing Record 18 of Set 15 | omboue
# Processing Record 19 of Set 15 | puerto ayacucho
# Processing Record 20 of Set 15 | nanchang
# Processing Record 21 of Set 15 | poya
# Processing Record 22 of Set 15 | okhotsk
# Processing Record 23 of Set 15 | chilliwack
# Processing Record 24 of Set 15 | kayes
# Processing Record 25 of Set 15 | bahia blanca
# Processing Record 26 of Set 15 | ler
# Processing Record 27 of Set 15 | khorramshahr
# Processing Record 28 of Set 15 | batemans bay
# Processing Record 29 of Set 15 | adeje
# Processing Record 30 of Set 15 | mentok
# City not found. Skipping...
# Processing Record 31 of Set 15 | klyuchi
# Processing Record 32 of Set 15 | kadykchan
# City not found. Skipping...
# Processing Record 33 of Set 15 | manokwari
# Processing Record 34 of Set 15 | palabuhanratu
# City not found. Skipping...
# Processing Record 35 of Set 15 | ust-kut
# Processing Record 36 of Set 15 | altamira
# Processing Record 37 of Set 15 | ostersund
# Processing Record 38 of Set 15 | tual
# Processing Record 39 of Set 15 | santo antonio do monte
# Processing Record 40 of Set 15 | port keats
# Processing Record 41 of Set 15 | tomatlan
# Processing Record 42 of Set 15 | maua
# Processing Record 43 of Set 15 | poum
# Processing Record 44 of Set 15 | srednekolymsk
# Processing Record 45 of Set 15 | mitu
# Processing Record 46 of Set 15 | trzebnica
# Processing Record 47 of Set 15 | san jose
# Processing Record 48 of Set 15 | plon
# Processing Record 49 of Set 15 | bend
# Processing Record 50 of Set 15 | mori
# Processing Record 1 of Set 16 | rocha
# Processing Record 2 of Set 16 | bereda
# Processing Record 3 of Set 16 | brumado
# Processing Record 4 of Set 16 | vidim
# Processing Record 5 of Set 16 | ambulu
# Processing Record 6 of Set 16 | satitoa
# City not found. Skipping...
# Processing Record 7 of Set 16 | alice springs
# Processing Record 8 of Set 16 | peniche
# Processing Record 9 of Set 16 | gobabis
# Processing Record 10 of Set 16 | irtyshskiy
# Processing Record 11 of Set 16 | pirogovskiy
# Processing Record 12 of Set 16 | kamenka
# Processing Record 13 of Set 16 | robertsport
# Processing Record 14 of Set 16 | hendrina
# Processing Record 15 of Set 16 | rameswaram
# Processing Record 16 of Set 16 | cartagena
# Processing Record 17 of Set 16 | paoua
# Processing Record 18 of Set 16 | zaozerne
# Processing Record 19 of Set 16 | thunder bay
# Processing Record 20 of Set 16 | sayalgudi
# City not found. Skipping...
# Processing Record 21 of Set 16 | biak
# Processing Record 22 of Set 16 | manzanillo
# Processing Record 23 of Set 16 | ongandjera
# Processing Record 24 of Set 16 | san andres
# Processing Record 25 of Set 16 | bokspits
# City not found. Skipping...
# Processing Record 26 of Set 16 | belaya gora
# Processing Record 27 of Set 16 | beira
# Processing Record 28 of Set 16 | morococha
# Processing Record 29 of Set 16 | viligili
# City not found. Skipping...
# Processing Record 30 of Set 16 | zhangye
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Herbertpur  30.4500   77.7333     89.06        57          95
# 1         Cape Town -33.9258   18.4232     55.89        90          75
# 2            Vanimo  -2.6741  141.3028     85.78        64          56
# 3            Kavali  14.9167   79.9833     88.75        55         100
# 4    Ribeira Grande  38.5167  -28.7000     66.27        86          38
# ..              ...      ...       ...       ...       ...         ...
# 709      San Andres  12.5847  -81.7006     82.42        83          40
# 710     Belaya Gora  68.5333  146.4167     70.50        32          97
# 711           Beira -19.8436   34.8389     65.84        92          58
# 712       Morococha -11.5997  -76.1411     31.50        63         100
# 713         Zhangye  38.9342  100.4517     83.53        23          93
#
#      Wind Speed Country Current Description
# 0          1.52      IN     overcast clouds
# 1         11.50      ZA          light rain
# 2          7.92      PG       broken clouds
# 3         19.39      IN     overcast clouds
# 4         13.02      PT    scattered clouds
# ..          ...     ...                 ...
# 709       12.66      CO        thunderstorm
# 710        7.23      RU     overcast clouds
# 711        3.11      MZ       broken clouds
# 712        5.21      PE     overcast clouds
# 713        4.52      CN     overcast clouds
#
# [714 rows x 9 columns]

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df[new_column_order]
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0        Herbertpur      IN  30.4500   77.7333     89.06        57
# 1         Cape Town      ZA -33.9258   18.4232     55.89        90
# 2            Vanimo      PG  -2.6741  141.3028     85.78        64
# 3            Kavali      IN  14.9167   79.9833     88.75        55
# 4    Ribeira Grande      PT  38.5167  -28.7000     66.27        86
# ..              ...     ...      ...       ...       ...       ...
# 709      San Andres      CO  12.5847  -81.7006     82.42        83
# 710     Belaya Gora      RU  68.5333  146.4167     70.50        32
# 711           Beira      MZ -19.8436   34.8389     65.84        92
# 712       Morococha      PE -11.5997  -76.1411     31.50        63
# 713         Zhangye      CN  38.9342  100.4517     83.53        23
#
#      Cloudiness  Wind Speed Current Description
# 0            95        1.52     overcast clouds
# 1            75       11.50          light rain
# 2            56        7.92       broken clouds
# 3           100       19.39     overcast clouds
# 4            38       13.02    scattered clouds
# ..          ...         ...                 ...
# 709          40       12.66        thunderstorm
# 710          97        7.23     overcast clouds
# 711          58        3.11       broken clouds
# 712         100        5.21     overcast clouds
# 713          93        4.52     overcast clouds
#
# [714 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
